# %% [markdown]
# # Exploratory Data Analysis: Social Media Posts by Campaign Ambassdors

# %%
import pandas as pd
import numpy as np
import requests

from openpyxl import Workbook
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

pd.options.display.float_format = "{:,.0f}".format
# %matplotlib inline

# %% [markdown]
# ### 1. Import data as Excel file

# %%
df = pd.read_excel("SocialMediaPosts_10092023.xlsx")

# %%
df.columns

# %%
# Strip whitespace from column names
df.columns = [column.strip() for column in df.columns]
# df.columns

# %%
df.head(2)

# %%
# Drop columns based on previous knowledge of the data

df.drop([
#     'CampaignName', 
    'Record #', 
#     'StartDate', 
#     'socialmediapost_platform',
    'socialmediapost_pageorhandle', 
    'socialmediapost_pagetype',
#     'socialmediapost_topic', 
    'socialmediapost_campaign',
#     'socialmediapost_content', 
#     'awareness_day', 
#     'socialmediapost_posttype',
    'socialmediapost_boosted_yesno', 
    'socialmediapost_paidcosts',
    'socialmediapost_reachtotal', 
    'socialmediapost_paidimpressions',
    'socialmediapost_impressionstotal',
#     'socialmediapost_engagementsreactions',
    'socialmediapost_engagementscomments',
#     'socialmediapost_engagementsshares',
    'socialmediapost_engagementslinkclicks', 
#     'socialmediapost_videoviews',
    'socialmediapost_bookmarked', 
#     'socialmediapost_urldirectedto',
    'sc_id_clicks', 
    'sc_page_views', 
    'audience_general',
    'audience_raceethnicity', 
    'audience_gendersexid', 
    'audience_age',
#     'audience_syndemic', 
#     'audience_hcp_type',
    'socialmediapost_stakeholders_partners', 
#     'Type_of_Ambassador',
    'socialmediapost_partner_role', 
#     'socialmediapost_comments',
    'ModifiedBy', 
    'OrganizationId', 
    'LockedBy', 
    'LockedDate',
    'SubmitForApprovalBy', 
    'ApprovedBy', 
    'ApprovedDate', 
    'CreatedDate',
    'ApprovalStatus', 
    'ModifiedDate'],
    axis=1,
    inplace=True)
# df
# Out:
#               CampaignName  Record #  StartDate socialmediapost_platform  \
# 0              Ambassadors       474 2021-01-04                 Facebook
# 1              Ambassadors       473 2021-01-06                 Facebook
# 2              Ambassadors       339 2021-01-06                Instagram
# 3              Ambassadors       518 2021-01-06                 Facebook
# 4              Ambassadors       519 2021-01-07                 Facebook
# ...                    ...       ...        ...                      ...
# 11463  Together - Provider     13553 2023-08-26                  Twitter
# 11464  Together - Provider     13554 2023-08-26                 Facebook
# 11465  Together - Provider     13408 2023-08-26                  Twitter
# 11466  Together - Provider     13555 2023-08-31                  Twitter
# 11467  Together - Provider     13556 2023-08-31                 Facebook
#
#       socialmediapost_topic  \
# 0                   (mixed)
# 1                   (other)
# ...

# %%
df.head(10).T
# Out:
#                                                                                       0  \
# CampaignName                                                                Ambassadors
# Record #                                                                            474
# StartDate                                                           2021-01-04 00:00:00
# socialmediapost_platform                                                       Facebook
# socialmediapost_topic                                                           (mixed)
# socialmediapost_content               Happy New Year! Let's take control of our heal...
# awareness_day                                                                       NaN
# socialmediapost_posttype                                                          Photo
# socialmediapost_engagementsreactions                                                 17
# socialmediapost_engagementsshares                                                     0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11468 entries, 0 to 11467
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   CampaignName                          11468 non-null  object
#  1   Record #                              11468 non-null  int64
#  2   StartDate                             11468 non-null  datetime64[ns]
#  3   socialmediapost_platform              11468 non-null  object
#  4   socialmediapost_topic                 11421 non-null  object
#  5   socialmediapost_content               11465 non-null  object
#  6   awareness_day                         1940 non-null   object
#  7   socialmediapost_posttype              11468 non-null  object
#  8   socialmediapost_engagementsreactions  11234 non-null  float64
#  9   socialmediapost_engagementsshares     11020 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                                       count  mean    std  min   25%   50%  \
# Record #                             11,468 6,713  4,088   20 3,150 6,158
# socialmediapost_engagementsreactions 11,234   100  2,071    0     2     9
# socialmediapost_engagementsshares    11,020    11    383    0     0     1
# socialmediapost_videoviews            9,950   564 18,791    0     0     0
#
#                                         75%       max
# Record #                             10,414    13,695
# socialmediapost_engagementsreactions     27   208,989
# socialmediapost_engagementsshares         6    40,037
# socialmediapost_videoviews                0 1,778,983

# %% [markdown]
# ### 2. Select data of interest

# %%
# Show the date range of entries
print('Oldest entry:',df['StartDate'].min())
print('Newest entry:',df['StartDate'].max())
# Out:
# Oldest entry: 2018-09-27 00:00:00
# Newest entry: 2023-09-30 00:00:00

# %%
# Look at all Ambassadors
ambassadors_mask = (df['CampaignName']=='Ambassadors')
df_ambassadors = (df[ambassadors_mask])
df_ambassadors.describe().T
# Out:
#                                       count  mean    std  min   25%   50%  \
# Record #                              3,152 6,006  4,251  316 1,945 5,720
# socialmediapost_engagementsreactions  3,150   178  3,804    0     1     6
# socialmediapost_engagementsshares     3,129    17    716    0     0     0
# socialmediapost_videoviews            2,904   858 33,131    0     0     0
#
#                                         75%       max
# Record #                             10,082    13,233
# socialmediapost_engagementsreactions     28   208,989
# socialmediapost_engagementsshares         1    40,037
# socialmediapost_videoviews                0 1,778,983

# %%
# Look at all Community Ambassadors
community_mask = (df['Type_of_Ambassador']=='Community')
df_community = (df[community_mask])
df_community.describe().T
# Out:
#                                       count  mean    std  min   25%   50%  \
# Record #                              2,730 5,907  4,267  316 1,091 5,475
# socialmediapost_engagementsreactions  2,728   200  4,087    0     1     6
# socialmediapost_engagementsshares     2,708    18    770    0     0     0
# socialmediapost_videoviews            2,496   991 35,735    0     0     0
#
#                                         75%       max
# Record #                             10,052    13,227
# socialmediapost_engagementsreactions     30   208,989
# socialmediapost_engagementsshares         1    40,037
# socialmediapost_videoviews                0 1,778,983

# %%
# Look at all Clinical Ambassadors
clinical_mask = (df['Type_of_Ambassador']=='Clinical')
df_clinical = (df[clinical_mask])
df_clinical.describe().T
# Out:
#                                       count  mean   std  min   25%   50%  \
# Record #                                395 6,917 4,092  534 3,368 7,475
# socialmediapost_engagementsreactions    395    35   106    0     2     5
# socialmediapost_engagementsshares       394     6    27    0     0     1
# socialmediapost_videoviews              381    43   357    0     0     0
#
#                                         75%    max
# Record #                             10,634 13,233
# socialmediapost_engagementsreactions     21  1,440
# socialmediapost_engagementsshares         3    440
# socialmediapost_videoviews                0  5,665
